# %%
import torch
input = torch.randn((3,4,5))
print(input.unsqueeze(-1).shape)
# Out:
# torch.Size([3, 4, 5, 1])

# %%
input = torch.randn((1,9,25))
input_1 = torch.randn((1024,256))
print(torch.matmul(input, input_1).squeeze(1).shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 input = torch.randn((1,9,25))
#       2 input_1 = torch.randn((1024,256))
# ----> 3 print(torch.matmul(input, input_1).squeeze(1).shape)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (9x25 and 1024x256)
